# %%
# !pip install pandas

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\envs\practise\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\envs\practise\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\envs\practise\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\envs\practise\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\anaconda3\envs\practise\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\anaconda3\envs\practise\lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\envs\practise\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\hp\anaconda3\envs\practise\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\envs\practise\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\envs\practise\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\envs\practise\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import pandas as pd

# %%
df=pd.read_csv("matches.csv")

# %% [markdown]
# # 1)How big is the Data

# %%
df.shape
# Out:
# (1095, 20)

# %% [markdown]
# # 2)How does the data Look like

# %%
df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
df.sample(5)
# Out:
#            id   season       city        date match_type player_of_match  \
# 89     392214     2009  Centurion  2009-05-07     League       ML Hayden
# 180    501203     2011    Kolkata  2011-04-11     League       JH Kallis
# 209    501233     2011      Kochi  2011-04-30     League        V Sehwag
# 808   1216506  2020/21  Abu Dhabi  2020-11-01     League      RD Gaikwad
# 1001  1359526     2023     Jaipur  2023-05-07     League     GD Phillips
#
#                                venue                  team1  \
# 89                   SuperSport Park    Chennai Super Kings
# 180                     Eden Gardens  Kolkata Knight Riders
# 209                    Nehru Stadium   Kochi Tuskers Kerala
# 808             Sheikh Zayed Stadium        Kings XI Punjab
# 1001  Sawai Mansingh Stadium, Jaipur       Rajasthan Royals
#
#                     team2            toss_winner toss_decision  \
# 89        Kings XI Punjab    Chennai Super Kings           bat
# 180       Deccan Chargers  Kolkata Knight Riders           bat
# 209      Delhi Daredevils       Delhi Daredevils           bat
# 808   Chennai Super Kings    Chennai Super Kings         field
# 1001  Sunrisers Hyderabad       Rajasthan Royals           bat
#
#                      winner   result  result_margin  target_runs  \
# 89      Chennai Super Kings     runs           12.0        187.0
# 180   Kolkata Knight Riders     runs            9.0        164.0
# 209        Delhi Daredevils     runs           38.0        158.0
# 808     Chennai Super Kings  wickets            9.0        154.0
# 1001    Sunrisers Hyderabad  wickets            4.0        215.0
#
#       target_overs super_over method          umpire1         umpire2
# 89            18.0          N    D/L        DJ Harper  TH Wijewardene
# 180           20.0          N    NaN      RE Koertzen     SK Tarapore
# 209           20.0          N    NaN  HDPK Dharmasena         AL Hill
# 808           20.0          N    NaN        PG Pathak       VK Sharma
# 1001          20.0          N    NaN      Nitin Menon    Vinod Seshan

# %% [markdown]
# # 3)What does the data types of cols

# %%
df.dtypes
# Out:
# id                   int64
# season              object
# city                object
# date                object
# match_type          object
# player_of_match     object
# venue               object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# target_runs        float64
# target_overs       float64
# super_over          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB

# %% [markdown]
# # 4)Are there any missing values

# %%
df.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %% [markdown]
# # 5)How deos the data look Mathematically

# %%
df.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %% [markdown]
# # 6) Are there are duplicate values?

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, match_type, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, target_runs, target_overs, super_over, method, umpire1, umpire2]
# Index: []

# %% [markdown]
# # 7) How is the correlation between col?

# %%
df.corr()

# %% [markdown]
# # Categorical Data

# %% [markdown]
# # 1. CountPlot

# %%
import seaborn as sns

# %%
sns.countplot(df['season'])
#df['season'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='count', ylabel='season'>

# %% [markdown]
# # 2. PieChart

# %%
df['season'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical Data

# %% [markdown]
# # 1. Histogram

# %%
  import matplotlib.pyplot as plt

# %%
plt.hist(df['season'],bins=23)
# Out:
# (array([58., 57., 60.,  0., 73., 74.,  0., 76., 60.,  0., 59., 60., 59.,
#          0., 60., 60.,  0., 60., 60.,  0., 74., 74., 71.]),
#  array([ 0.        ,  0.69565217,  1.39130435,  2.08695652,  2.7826087 ,
#          3.47826087,  4.17391304,  4.86956522,  5.56521739,  6.26086957,
#          6.95652174,  7.65217391,  8.34782609,  9.04347826,  9.73913043,
#         10.43478261, 11.13043478, 11.82608696, 12.52173913, 13.2173913 ,
#         13.91304348, 14.60869565, 15.30434783, 16.        ]),
#  <BarContainer object of 23 artists>)

# %% [markdown]
# # 2. Displot

# %%
sns.displot(df['season'])

# %% [markdown]
# # 3. BoxPlot

# %%
sns.boxplot(df['season'])
# Out:
# <Axes: ylabel='season'>
